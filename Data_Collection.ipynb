# %% [markdown]
# ## Song Lyrics Generator
#
# #### Problem Statement
# Overcoming writers block and writing creative lyrics is difficult task for most musicians, which leads to frustration and feeling "stuck". For this project, I am hoping to create a text generation model that predicts the next word, couple words, or line of text for a new song in order to help musicians create awesome new lyrics.
#
# #### Proposed Method and Models
# - Gpt-2 to train my model -- Depending on the output, it would be interesting to let the user select a single artist they want their lyrics to sound like (MVP). It would also be interesting if I pulled from Spotify a list of similar artists and grouped them together to create another model, showcasing my ability to cluster. In addition, I could also create a generator by genre (which would require me to get a list of the top songs by genre and train a model for each)
# - Flask App
# - NLP
# - AWS
#
# #### Risks and Assumptions of My Data
# - Will have a large variety of artists and the lyrics to each of their songs
# - I could have duplicates of the same song
# - Song lyrics can be abstract, which I am not sure yet how that might affect my model
# - The score of the model can be subjective
#
# #### Initial Goals and Success Criteria
# - Predict either the next word, words, or line of a song based on an text input from the user
# - Consider using a BLEURT Score as a metric of success - https://medium.com/@jrodthoughts/googles-bleurt-is-bert-for-evaluating-natural-language-generation-models-fa0ce898c38a.
# - Give the user multiple options for the next word(s), score on the number of accepted recommendations
# - Rhyme (stretch)
# - Write an original song with > 50% of the lyrics computer generated
#
# #### Initial Data Source and EDA
# I plan to pull a handful more artists and add them as csvs. With the function below, the biggest hurdle is the amount of time is takes to scrape the large pulls of data, but it is a repeatable process that I could let run during off hours. I have not fully decided if I am going to integrate the Spotify API data, which is why I've tried to pull the `spotify_url` from the songs below. I may be able to look up by the `id` or worst case can use the `artist_name` with the `title` .

# %%
#Keep my access token secret

with open('./token.txt', 'r') as f:
    token = f.read().replace('\n', '')

# %%
#Credit: https://lyricsgenius.readthedocs.io/en/master/index.html
from lyricsgenius import Genius
import pandas as pd
import numpy as np
import json
import os

genius = Genius(token, 
                sleep_time = 1, #don't overload the servers
                remove_section_headers=True) #removes [Chorus], [Bridge], etc. headers from lyrics.
                #verbose=False will stop the pull from printing

# %% [markdown]
# # Scrape Lyrics from Multiple Artists

# %% [markdown]
# **Artists**
# - John Mayer
# - Jack Johnson
# - ...(will add more)

# %%
john_mayer = genius.search_artist('John Mayer')
jack_johnson = genius.search_artist('Jack Johnson')
# Out:
# Searching for songs by John Mayer...
#
# Song 1: "New Light"
# Song 2: "Gravity"
# Song 3: "Slow Dancing in a Burning Room"
# Song 4: "Free Fallin’"
# Song 5: "In the Blood"
# Song 6: "You’re Gonna Live Forever in Me"
# Song 7: "Daughters"
# Song 8: "Stop This Train"
# Song 9: "Moving On and Getting Over"
# Song 10: "Wildfire Interlude"
# Song 11: "Still Feel Like Your Man"
# Song 12: "Waiting on the World to Change"
# Song 13: "Rosie"
# Song 14: "Paper Doll"
# Song 15: "In Your Atmosphere"
# Song 16: "Emoji of a Wave"
# Song 17: "Love on the Weekend"
# Song 18: "Edge of Desire"
# Song 19: "Your Body Is a Wonderland"
# Song 20: "No Such Thing"
# Song 21: "Carry Me Away"
# Song 22: "Who Says"
# Song 23: "Never on the Day You Leave"
# Song 24: "Half of My Heart"
# Song 25: "Who You Love"
# Song 26: "XO"
# Song 27: "Born and Raised"
# Song 28: "I Don’t Trust Myself (With Loving You)"
# Song 29: "Helpless"
# Song 30: "Neon"
# Song 31: "Walt Grace’s Submarine Test, January 1967"
# Song 32: "Why Georgia"
# Song 33: "Dreaming With a Broken Heart"
# Song 34: "Heartbreak Warfare"
# Song 35: "The Heart of Life"
# Song 36: "Dear Marie"
# Song 37: "Belief"
# Song 38: "Vultures"
# Song 39: "Say"
# Song 40: "Changing"
# Song 41: "Wildfire"
# Song 42: "I’m Gonna Find Another You"
# Song 43: "Waitin’ on the Day"
# Song 44: "Roll It On Home"
# Song 45: "Bold as Love"
# Song 46: "I Will Be Found (Lost at Sea)"
# Song 47: "Clarity"
# Song 48: "Queen of California"
# Song 49: "Assassin"
# Song 50: "I Guess I Just Feel Like"
# Song 51: "Something Like Olivia"
# Song 52: "The Age of Worry"
# Song 53: "In Repair"
# Song 54: "On The Way Home"
# Song 55: "Friends, Lovers or Nothing"
# Song 56: "Comfortable"
# Song 57: "My Stupid Mouth"
# Song 58: "Covered in Rain"
# Song 59: "Split Screen Sadness"
# Song 60: "3x5"
# Song 61: "You’re No One ’Til Someone Lets You Down"
# Song 62: "A Face To Call Home"
# Song 63: "Something’s Missing"
# Song 64: "St. Patrick’s Day"
# Song 65: "Shadow Days"
# Song 66: "Whiskey, Whiskey, Whiskey"
# Song 67: "Badge and Gun"
# Song 68: "Wheel"
# Song 69: "Perfectly Lonely"
# Song 70: "City Love"
# Song 71: "83"
# Song 72: "Back to You"
# Song 73: "If I Ever Get Around To Living"
# Song 74: "All We Ever Do Is Say Goodbye"
# Song 75: "Love is a Verb"
# Song 76: "Bigger Than My Body"
# Song 77: "Call Me the Breeze"
# Song 78: "Come Back to Bed"
# Song 79: "War of My Life"
# Song 80: "Theme from “The Search for Everything”"
# Song 81: "Speak for Me"
# Song 82: "Hotel Bathroom Song"
# Song 83: "Victoria"
# Song 84: "Love Song for No One"
# Song 85: "I Just Remembered That I Didn’t Care"
# Song 86: "New Deep"
# Song 87: "Do You Know Me"
# Song 88: "Born and Raised (Reprise)"
# Song 89: "Not Myself"
# Song 90: "The Search for Everything (Poem)"
# Song 91: "Crossroads"
# Song 92: "Home Life"
# Song 93: "Fool to Love You"
# Song 94: "Great Indoors"
# Song 95: "Hummingbird"
# Song 96: "I Don’t Need No Doctor"
# Song 97: "Only Heart"
# Song 98: "I’m On Fire"
# Song 99: "Route 66"
# Song 100: "Go Easy On Me"
# Song 101: "The Hurt"
# Song 102: "Quiet"
# Song 103: "Man On The Side"
# Song 104: "Lenny / Man On The Side"
# Song 105: "Love Soon"
# Song 106: "Sucker"
# Song 107: "I’ve Got Dreams To Remember/Gravity"
# Song 108: "Tracing"
# Song 109: "Blue Skies at Night"
# Song 110: "This Will All Make Perfect Sense Someday"
# Song 111: "The Heart Of Life/In Repair"
# Song 112: "83 Medley"
# Song 113: "Lifelines"
# Song 114: "In your atmosphere - live at the nokia theatre"
# Song 115: "Breakaway"
# Song 116: "Neon (12:47 Am)"
# Song 117: "In Your Atmosphere [Live]"
# Song 118: "Gravity (live)"
# Song 119: "Covered in rain - live in birmingham"
# Song 120: "Why Georgia - Live in Birmingham"
# Song 121: "Faith"
# Song 122: "Break In The Clouds"
# Song 123: "Slow dancing in a burning room - live at the nokia theatre"
# Song 124: "Message In A Bottle"
# Song 125: "Comfortable - live in birmingham"
# Song 126: "I Pet Your Cat A New Way"
# Song 127: "Comfortable (Live)"
# Song 128: "All along the watchtower"
# Song 129: "Neon - live at the nokia theatre"
# Song 130: "Waiting on the World to Change (feat. Ben Harper)"
# Song 131: "Money For Nothing"
# Song 132: "Vultures (live)"
# Song 133: "Belief (live)"
# Song 134: "Daughters (Home demo)"
# Song 135: "My Stupid Mouth-Live in Birmingham"
# Song 136: "The Wind Cries Mary"
# Song 137: "Daughters - live at the nokia theatre"
# Song 138: "Ain’t Gonna Give Up On Love"
# Song 139: "Like a Rolling Stone (live)"
# Song 140: "Something Like Olivia (acoustic live)"
# Song 141: "Stop this train - live at the nokia theatre"
# Song 142: "Wanna Be Startin’ Somethin’"
# Song 143: "Good Love Is On The Way - Acoustic"
# Song 144: "I’m gonna find another you - live at the nokia theatre"
# Song 145: "Good love is on the way - live at the nokia theatre"
# Song 146: "Out of my mind - live at the nokia theatre"
# Song 147: "Lenny"
# Song 148: "3x5 - live in birmingham"
# Song 149: "Outside in the Underground"
# Song 150: "George’s Blues"
# Song 151: "In Repair (acoustic version)"
# Song 152: "Queen of California (acoustic live)"
# Song 153: "Daughters - live in ohio"
# Song 154: "Inner City Blues (Make Me Wanna Holler)"
# Song 155: "Untitled"
# Song 156: "Who did you think i was - live at the nokia theatre"
# Song 157: "Clarity - live in ohio"
# Song 158: "Your body is a wonderland - radio version"
# Song 159: "Why georgia - live at the nokia theatre"
# Song 160: "Vultures - live at the nokia theatre"
# Song 161: "Belief - live at the nokia theatre"
# Song 162: "Back to you - ep version"
# Song 163: "Wheel - live in ohio"
# Song 164: "3x5 - live in ohio"
# Song 165: "Can’t Take That Plane"
# Song 166: "My stupid mouth - demo version"
# Song 167: "No such thing - demo version"
# Song 168: "Panama"
# Song 169: "83 medley - live in birmingham"
# Song 170: "Kid A (Radiohead Cover)"
# Song 171: "Shadow Days (acoustic live)"
# Song 172: "Heartbreak Warfare (Top 40 edit)"
# Song 173: "Victoria - ep version"
# Song 174: "Your body is a wonderland - live in birmingham"
# Song 175: "Route 66 (Extended Film Version)"
# Song 176: "Everyday i have the blues - live at the nokia theatre"
# Song 177: "Covered in rain - live in philadlephia,pa & hartford, ct"
# Song 178: "Split screen sadness - live at the shoreline amphitheater"
# Song 179: "Wait until tomorrow - live at the nokia theatre"
# Song 180: "Waiting on the world to change - live at the nokia theatre"
# Song 181: "Come When I Call - Live at the Nokia Theatre"
# Song 182: "Love soon - ep version"
# Song 183: "Come back to bed - live version"
# Song 184: "Monopoly"
# Song 185: "City love - live in birmingham"
# Song 186: "Back to you - live in birmingham"
# Song 187: "The Wind Cries Mary (Live At The X-Lounge)"
# Song 188: "Lenny / man on the side - live in birmingham"
# Song 189: "Heartbreak warfare - radio edit"
# Song 190: "Your body is a wonderland - live in philadlephia,pa & hartford, ct"
# Song 191: "Bigger than my body - live at the shoreline amphitheater"
# Song 192: "No Such Thing (live)"
# Song 193: "Man On The Side (Acoustic)"
# Song 194: "Neon - live version"
# Song 195: "Blues intro - live at c.w. mitchell pavillion"
# Song 196: "Something’s missing - live in ohio"
# Song 197: "I don’t need no doctor - live at the nokia theatre"
# Song 198: "New deep - live in ohio"
# Song 199: "Love song for no one - live in birmingham"
# Song 200: "Neon - live in birmingham"
# Song 201: "Quiet - live in ohio"
# Song 202: "Hummingbird - live in philadlephia,pa & hartford, ct"
# Song 203: "Something’s missing - live in birmingham"
# Song 204: "Daughters (Electric Guitar mix)"
# Song 205: "Only heart - live in ohio"
# Song 206: "Inner city blues (make me wanna holler) - live from kansas city"
# Song 207: "Come back to bed - live at the shoreline amphitheater"
# Song 208: "83 - live in philadlephia,pa & hartford, ct"
# Song 209: "Come back to bed - live at c.w. mitchell pavillion"
# Song 210: "Why georgia - live at the shoreline amphitheater"
# Song 211: "Comfortable - live at c.w. mitchell pavillion"
# Song 212: "Something’s missing - live at the shoreline amphitheater"
# Song 213: "Wildfire - live from red rocks"
# Song 214: "My stupid mouth - live in ohio"
# Song 215: "Bigger than my body - live at c.w. mitchell pavillion"
# Song 216: "No such thing - live in birmingham"
# Song 217: "Speak for Me (acoustic live)"
# Song 218: "The Toffee Song"
# Song 219: "No such thing - live in ohio"
# Song 220: "Daughters - live at c.w. mitchell pavillion"
# Song 221: "My stupid mouth - live in philadlephia,pa & hartford, ct"
# Song 222: "Message in a bottle - live in birmingham"
# Song 223: "Back to you - live at c.w. mitchell pavillion"
# Song 224: "Neon - live at c.w. mitchell pavillion"
# Song 225: "Clarity - live at c.w. mitchell pavillion"
# Song 226: "No such thing - live at the shoreline amphitheater"
# Song 227: "Lenny (Live At The X-Lounge)"
# Song 228: "New deep - live at the shoreline amphitheater"
# Song 229: "Something’s missing - live in philadlephia,pa & hartford, ct"
# Song 230: "Your body is a wonderland - live at c.w. mitchell pavillion"
# Song 231: "Only heart - live in philadlephia,pa & hartford, ct"
# Song 232: "New deep - live in philadlephia,pa & hartford, ct"
# Song 233: "No such thing - live at c.w. mitchell pavillion"
# Song 234: "Come back to bed - live in philadlephia,pa & hartford, ct"
# Done. Found 234 songs.
# Searching for songs by Jack Johnson...
#
# Song 1: "Banana Pancakes"
# Song 2: "Better Together"
# Song 3: "Upside Down"
# Song 4: "Flake"
# Song 5: "Sitting, Waiting, Wishing"
# Song 6: "My Mind Is For Sale"
# Song 7: "Do You Remember"
# Song 8: "Sunsets For Somebody Else"
# Song 9: "Angel"
# Song 10: "Home"
# Song 11: "Breakdown"
# Song 12: "Bubble Toes"
# Song 13: "Good People"
# Song 14: "Never Know"
# Song 15: "Taylor"
# Song 16: "Belle"
# Song 17: "Love Song #16"
# Song 18: "No Other Way"
# Song 19: "Sleep Through The Static"
# Song 20: "I Got You"
# Song 21: "Staple It Together"
# Song 22: "Only the Ocean"
# Song 23: "Gone"
# Song 24: "If I Could"
# Song 25: "We’re Going To Be Friends"
# Song 26: "Go On"
# Song 27: "You and Your Heart"
# Song 28: "Constellations"
# Song 29: "All At Once"
# Song 30: "Escape (The Piña Colada Song)"
# Song 31: "Hope"
# Song 32: "You Can’t Control It"
# Song 33: "Subplots"
# Song 34: "My Little Girl"
# Song 35: "If I Had Eyes"
# Song 36: "Crying Shame"
# Song 37: "Broken"
# Song 38: "Traffic In The Sky"
# Song 39: "In The Morning"
# Song 40: "Washing Dishes"
# Song 41: "Inaudible Melodies"
# Song 42: "Big Sur"
# Song 43: "Spring Wind"
# Song 44: "Shot Reverse Shot"
# Song 45: "Fragments"
# Song 46: "Talk Of The Town"
# Song 47: "Girl I Wanna Lay You Down"
# Song 48: "Daybreaks"
# Song 49: "Fortunate Fool"
# Song 50: "Situations"
# Song 51: "Rodeo Clowns"
# Song 52: "To the Sea"
# Song 53: "What You Thought You Need"
# Song 54: "Cookie Jar"
# Song 55: "Imagine"
# Song 56: "Ones And Zeros"
# Song 57: "You Remind Me Of You"
# Song 58: "Angel / Better Together - Live In Paris, France/2008"
# Song 59: "The 3 R’s"
# Song 60: "Losing Keys"
# Song 61: "Is One Moon Enough?"
# Song 62: "Times Like These"
# Song 63: "Monsoon"
# Song 64: "In Between Dreams Medley"
# Song 65: "It’s All Understood"
# Song 66: "Never Fade"
# Song 67: "Wasting Time"
# Song 68: "Questions"
# Song 69: "Supposed To Be"
# Song 70: "Wrong Turn"
# Song 71: "F-Stop Blues"
# Song 72: "Tomorrow Morning"
# Song 73: "Sexy Plexi"
# Song 74: "Seasick Dream"
# Song 75: "Dreams Be Dreams"
# Song 76: "Drink The Water"
# Song 77: "Adrift"
# Song 78: "Holes To Heaven"
# Song 79: "Tape Deck"
# Song 80: "New Axe"
# Song 81: "Enemy"
# Song 82: "The News"
# Song 83: "Rainbow"
# Song 84: "Don’t Believe A Thing I Say"
# Song 85: "Posters"
# Song 86: "Cocoon"
# Song 87: "A Pirate Looks At Forty"
# Song 88: "With My Own Two Hands"
# Song 89: "Plastic Jesus/Fall Line/Spring Wind"
# Song 90: "Same Girl"
# Song 91: "Belle / Banana Pancakes - Live in Paris, France/2008"
# Song 92: "People Watching"
# Song 93: "Little Bit Of Love"
# Song 94: "Fall Line"
# Song 95: "Symbol In My Driveway"
# Song 96: "From the Clouds"
# Song 97: "Gather"
# Song 98: "At Or With Me"
# Song 99: "Radiate"
# Song 100: "No Good With Faces"
# Song 101: "As I Was Saying"
# Song 102: "Rudolph The Red-Nosed Reindeer"
# Song 103: "The Horizon Has Been Defeated"
# Song 104: "The Sharing Song"
# Song 105: "Losing Hope"
# Song 106: "Change"
# Song 107: "Middle Man"
# Song 108: "They Do, They Don’t"
# Song 109: "High Tide Or Low Tide"
# Song 110: "Lullaby"
# Song 111: "Anything But the Truth"
# Song 112: "While We Wait"
# Song 113: "Mediocre Bad Guys"
# Song 114: "Mudfootball"
# Song 115: "Island Style"
# Song 116: "Red Wine, Mistakes, Mythology"
# Song 117: "Turn Your Love"
# Song 118: "Cupid"
# Song 119: "Badfish/Boss D.J."
# Song 120: "Brushfire Fairytales"
# Song 121: "When I Look Up"
# Song 122: "I Shall Be Released"
# Song 123: "Pictures of People Taking Pictures"
# Song 124: "A Brokedown Melody"
# Song 125: "Someday At Christmas"
# Song 126: "The Upsetter"
# Song 127: "Mama, You’ve Been On My Mind/A Fraction Of Last Thoughts On Woody Guthrie"
# Song 128: "Mudfootball (For Moe Lerner)"
# Song 129: "Bubble Toes / Express Yourself - Live at Outside Lands, San Francisco, California/2008"
# Song 130: "Cry Cry Cry"
# Song 131: "Jungle Gym"
# Song 132: "Who’s To Say"
# Song 133: "Welcome To Jamrock"
# Song 134: "Sunshine"
# Song 135: "Take it Easy"
# Song 136: "Let It Be Sung"
# Song 137: "Rocky Raccoon"
# Song 138: "Pirate Looks At 40"
# Song 139: "Walk Alone"
# Song 140: "Country Road - Live in Santa Barbara, California/2008"
# Song 141: "Frankie And Albert"
# Song 142: "Alien Casinos"
# Song 143: "Free"
# Song 144: "Angel (Holiday)"
# Song 145: "Blue Eyes Crying In the Rain"
# Song 146: "Thicker Than Water"
# Song 147: "Staple It Together - Live In San Diego, California/2008"
# Song 148: "Do You Remember / Remember - Live in Santa Barbara, California/2008"
# Song 149: "Think Clearly"
# Song 150: "Last Thoughts on Woody Guthrie"
# Song 151: "Holiday"
# Song 152: "Further On Down The Road"
# Song 153: "The Faultline"
# Song 154: "Poor Taylor"
# Song 155: "Moonshine"
# Song 156: "Haleiwa"
# Song 157: "Give It To You"
# Song 158: "Goodbye"
# Song 159: "Wasting Time - Live in George, Washington/2008"
# Song 160: "Just Can’t Go To Sleep"
# Song 161: "If I Had Eyes - Live at the Kōkua Festival, Honolulu, Hawaii/2008"
# Song 162: "I Can’t Go to Sleep (circa 1998)"
# Song 163: "Fortunate Fools"
# Song 164: "What You Thought You Need - Live at Kōkua Festival, Honolulu, Hawaii/2008"
# Song 165: "The Horizon Has Been Defeated / Mother and Child Reunion - Live at Bonnaroo, Manchester, Tennessee/2008"
# Song 166: "Sleep Through The Static - Live in Paris, France/2008"
# Song 167: "Outro"
# Song 168: "Sitting, Waiting, Wishing - Live In Barcelona, Spain/2008"
# Song 169: "Sydney Rhame"
# Song 170: "Tomorrow Morning Comes"
# Song 171: "Flake - Live at Outside Lands, San Francisco, California/2008"
# Song 172: "Home - Live at the Kōkua Festival, Honolulu, Hawaii"
# Song 173: "Better Together (One World: Together At Home)"
# Song 174: "All At Once - Live In Barcelona, Spain/2008"
# Song 175: "The Cove"
# Song 176: "Nice Car, Boy"
# Song 177: "Good people - Live At Bonnaroo, Manchester, Tennessee/2008"
# Song 178: "Constellations - Live at Bonnaroo, Manchester, Tennessee/2008"
# Song 179: "Times Like These - Live In Santa Barbara, California/2008"
# Song 180: "Secret Heart"
# Song 181: "Gone - Live In Morrisson, Colorado/2008"
# Done. Found 181 songs.

# %% [markdown]
# ## Save output as a json file

# %%
genius.save_artists(artists=[john_mayer, jack_johnson], overwrite=True)
# Out:
# tmp_lyrics/tmp_0_JohnMayer
# Wrote `Lyrics_JohnMayer.json`
# tmp_lyrics/tmp_1_JackJohnson
# Wrote `Lyrics_JackJohnson.json`
# Time elapsed: 0.00010644555091857911 hours

# %% [markdown]
# # Function to Create Lyrics Dataframe for each artist

# %%
data['songs'][232]['media']
# Out:
# []

# %%
len(data['songs'][221]['media'])
# Out:
# 0

# %%
spotify_url = []
for song in range(0,len(data['songs'])): #for each song
    if len(data['songs'][song]['media']) > 0: #are there any values in media?

        #store a list of providers to later check if spotify is in that list
        contains_spotify = [data['songs'][song]['media'][item]['provider'] for item in range(0,len(data['songs'][song]['media']))] 
        
        if 'spotify' in contains_spotify: 
            for item in range(0,len(data['songs'][song]['media'])):  #loop through each item
                if (data['songs'][song]['media'][item]['provider'] == 'spotify'): #find the item that is spotify
                    spotify_url.append(data['songs'][song]['media'][item]['url']) #add the url 
        else:
            spotify_url.append('NA')
    else:
        spotify_url.append('NA')
# Out:
# 234

# %%
def get_lyrics(filename):
    
    # Reading the json as a dict
    with open(filename) as json_data:
        data = json.load(json_data)

    #Source credit: https://stackoverflow.com/questions/28373282/how-to-read-a-json-dictionary-type-file-with-pandas
    
    #need to account for that every song doesn't have a spotify url
    spotify_url = []
    for song in range(0,len(data['songs'])): #for each song
        if len(data['songs'][song]['media']) > 0: #are there any values in media?

            #store a list of providers to later check if spotify is in that list
            contains_spotify = [data['songs'][song]['media'][item]['provider'] for item in range(0,len(data['songs'][song]['media']))] 

            if 'spotify' in contains_spotify: 
                for item in range(0,len(data['songs'][song]['media'])):  #loop through each item
                    if (data['songs'][song]['media'][item]['provider'] == 'spotify'): #find the item that is spotify
                        spotify_url.append(data['songs'][song]['media'][item]['url']) #add the url 
            else:
                spotify_url.append('NA')
        else:
            spotify_url.append('NA')
    
    #create a dataframe
    df =  pd.DataFrame({

        #multiply by length of songs in json response to create a new row for each
        'artist_name' : [data['name']] * len(data['songs']),                                              #artist name
        'image_url' : [data['image_url']] * len(data['songs']),                                           #thumbnail image
        'url' : [data['url']] * len(data['songs']),                                                       #genius url

        #song data
        'title' : [data['songs'][item]['title'] for item in range(0,len(data['songs']))],                 #title of each song
        'lyrics' : [data['songs'][item]['lyrics'] for item in range(0,len(data['songs']))],                #song lyrics           
        'spotify_url' :  spotify_url, #spotify url


    })
    return df

# %% [markdown]
# ### Collect data for each artist

# %%
john_mayer_df = get_lyrics('Lyrics_JohnMayer.json')
john_mayer_df.head(3)
# Out:
#   artist_name                                          image_url  \
# 0  John Mayer  https://images.genius.com/4c443bf06bf6b696ad4f...
# 1  John Mayer  https://images.genius.com/4c443bf06bf6b696ad4f...
# 2  John Mayer  https://images.genius.com/4c443bf06bf6b696ad4f...
#
#                                      url                           title  \
# 0  https://genius.com/artists/John-mayer                       New Light
# 1  https://genius.com/artists/John-mayer                         Gravity
# 2  https://genius.com/artists/John-mayer  Slow Dancing in a Burning Room
#
#                                               lyrics  \
# 0  Ah, ah, ah\nAh...\n\nI'm the boy in your other...
# 1  Gravity is working against me\nAnd gravity wan...
# 2  It's not a silly little moment\nIt's not the s...
#
#                                          spotify_url
# 0  https://open.spotify.com/track/3bH4HzoZZFq8UpZ...
# 1  https://open.spotify.com/track/52K3qt1rCYf3Ciu...
# 2  https://open.spotify.com/track/3f8Uygfz3CIpUCo...

# %%
jack_johnson_df = get_lyrics('Lyrics_JackJohnson.json')
jack_johnson_df
# Out:
#       artist_name                                          image_url  \
# 0    Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 1    Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 2    Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 3    Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 4    Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# ..            ...                                                ...
# 176  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 177  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 178  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 179  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 180  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
#
#                                          url  \
# 0    https://genius.com/artists/Jack-johnson
# 1    https://genius.com/artists/Jack-johnson
# 2    https://genius.com/artists/Jack-johnson
# 3    https://genius.com/artists/Jack-johnson
# 4    https://genius.com/artists/Jack-johnson
# ..                                       ...
# 176  https://genius.com/artists/Jack-johnson
# 177  https://genius.com/artists/Jack-johnson
# 178  https://genius.com/artists/Jack-johnson
# 179  https://genius.com/artists/Jack-johnson
# 180  https://genius.com/artists/Jack-johnson
#
#                                                  title  \
# 0                                      Banana Pancakes
# 1                                      Better Together
# 2                                          Upside Down
# 3                                                Flake
# 4                            Sitting, Waiting, Wishing
# ..                                                 ...
# 176  Good people - Live At Bonnaroo, Manchester, Te...
# 177  Constellations - Live at Bonnaroo, Manchester,...
# 178  Times Like These - Live In Santa Barbara, Cali...
# 179                                       Secret Heart
# 180            Gone - Live In Morrisson, Colorado/2008
#
#                                                 lyrics  \
# 0    Can't you see that it's just raining?\nThere a...
# 1    There is no combination of words\nI could put ...
# 2    Who's to say what's impossible?\nWell they for...
# 3    I know she said it's alright\nBut you can make...
# 4    Well I was sitting, waiting, wishing\nYou beli...
# ..                                                 ...
# 176  Well, you win, it's your show now\nSo what's i...
# 177  The light was leaving in the west it was blue\...
# 178  In times like these\nIn times like those\nWhat...
# 179  Secret Heart, what are you made of?\nWhat are ...
# 180  One, two\nWell look at all those fancy clothes...
#
#                                            spotify_url
# 0    https://open.spotify.com/track/451GvHwY99NKV4z...
# 1    https://open.spotify.com/track/4VywXu6umkIQ2OS...
# 2    https://open.spotify.com/track/2s1rRlb24PuFv80...
# 3    https://open.spotify.com/track/09dOpua4kGcHzH9...
# 4    https://open.spotify.com/track/5eWOsyHHic4vJP3...
# ..                                                 ...
# 176                                                 NA
# 177                                                 NA
# 178                                                 NA
# 179                                                 NA
# 180                                                 NA
#
# [181 rows x 6 columns]

# %% [markdown]
# # Stack the  Dataframes

# %%
all_songs_df = pd.concat([john_mayer_df,jack_johnson_df])
all_songs_df
# Out:
#       artist_name                                          image_url  \
# 0      John Mayer  https://images.genius.com/4c443bf06bf6b696ad4f...
# 1      John Mayer  https://images.genius.com/4c443bf06bf6b696ad4f...
# 2      John Mayer  https://images.genius.com/4c443bf06bf6b696ad4f...
# 3      John Mayer  https://images.genius.com/4c443bf06bf6b696ad4f...
# 4      John Mayer  https://images.genius.com/4c443bf06bf6b696ad4f...
# ..            ...                                                ...
# 176  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 177  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 178  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 179  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
# 180  Jack Johnson  https://s3.amazonaws.com/rapgenius/Jack+Johnso...
#
#                                          url  \
# 0      https://genius.com/artists/John-mayer
# 1      https://genius.com/artists/John-mayer
# 2      https://genius.com/artists/John-mayer
# 3      https://genius.com/artists/John-mayer
# 4      https://genius.com/artists/John-mayer
# ..                                       ...
# 176  https://genius.com/artists/Jack-johnson
# 177  https://genius.com/artists/Jack-johnson
# 178  https://genius.com/artists/Jack-johnson
# 179  https://genius.com/artists/Jack-johnson
# 180  https://genius.com/artists/Jack-johnson
#
#                                                  title  \
# 0                                            New Light
# 1                                              Gravity
# 2                       Slow Dancing in a Burning Room
# 3                                         Free Fallin’
# 4                                         In the Blood
# ..                                                 ...
# 176  Good people - Live At Bonnaroo, Manchester, Te...
# 177  Constellations - Live at Bonnaroo, Manchester,...
# 178  Times Like These - Live In Santa Barbara, Cali...
# 179                                       Secret Heart
# 180            Gone - Live In Morrisson, Colorado/2008
#
#                                                 lyrics  \
# 0    Ah, ah, ah\nAh...\n\nI'm the boy in your other...
# 1    Gravity is working against me\nAnd gravity wan...
# 2    It's not a silly little moment\nIt's not the s...
# 3    She's a good girl, loves her mama\nLoves Jesus...
# 4    How much of my mother has my mother left in me...
# ..                                                 ...
# 176  Well, you win, it's your show now\nSo what's i...
# 177  The light was leaving in the west it was blue\...
# 178  In times like these\nIn times like those\nWhat...
# 179  Secret Heart, what are you made of?\nWhat are ...
# 180  One, two\nWell look at all those fancy clothes...
#
#                                            spotify_url
# 0    https://open.spotify.com/track/3bH4HzoZZFq8UpZ...
# 1    https://open.spotify.com/track/52K3qt1rCYf3Ciu...
# 2    https://open.spotify.com/track/3f8Uygfz3CIpUCo...
# 3    https://open.spotify.com/track/4LloVtxNZpeh7q7...
# 4    https://open.spotify.com/track/77Y57qRJBvkGCUw...
# ..                                                 ...
# 176                                                 NA
# 177                                                 NA
# 178                                                 NA
# 179                                                 NA
# 180                                                 NA
#
# [415 rows x 6 columns]

# %%
all_songs_df[all_songs_df['spotify_url'] == 'NA'].shape
# Out:
# (313, 6)

# %%
#save as a csv
all_songs_df.to_csv('all_songs.csv', index=False)

# %% [markdown]
# # Create a Dataframe with all of the lyrics in one cell by artist

# %%
lyrics_df = pd.DataFrame(list(all_songs_df.groupby('artist_name')['lyrics']),columns=['artist_name','lyrics'])
lyrics_df
# Out:
#     artist_name                                             lyrics
# 0  Jack Johnson  0      Can't you see that it's just raining?\n...
# 1    John Mayer  0      Ah, ah, ah\nAh...\n\nI'm the boy in you...

# %%
#save as a csv
lyrics_df.to_csv('lyrics_df.csv', index=False)

# %% [markdown]
# ### MISC

# %%
all_songs_df['title'].str.cat(sep=' ')
# Out:
# 'New Light Gravity Slow Dancing in a Burning Room Banana Pancakes Better Together Upside Down'

# %%
' '.join(all_songs_df['title'])
# Out:
# 'New Light Gravity Slow Dancing in a Burning Room Banana Pancakes Better Together Upside Down'

# %%
#when add more artists can loop through like this in one function
for filename in os.listdir('./'):
    if filename.startswith('Lyrics_'):
        print(filename)
# Out:
# Lyrics_JohnMayer.json
# Lyrics_JackJohnson.json
